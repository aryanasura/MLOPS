# %%
from datetime import date
import yfinance as yf
import pandas as pd
import numpy as np

# %%
# Specify the stock symbol, from date, and to date
stock = 'ANUP.NS'
from_date = date(2024, 1, 1)
to_date = date.today()

# %%
data = yf.download(stock, start=from_date, end=to_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
# Price         Adj Close        Close  ... purchase number_of_stocks
# Ticker          ANUP.NS      ANUP.NS  ...
# Date                                  ...
# 2024-01-01  1345.895386  1349.625000  ...      NaN                1
# 2024-01-02  1330.163940  1333.849976  ...      NaN                2
# 2024-01-03  1350.657227  1354.400024  ...      NaN                3
# 2024-01-04  1350.931519  1354.675049  ...      NaN                4
# 2024-01-05  1350.482666  1354.224976  ...      NaN                5
# ...                 ...          ...  ...      ...              ...
# 2024-11-19  3413.850098  3413.850098  ...      NaN              218
# 2024-11-21  3488.350098  3488.350098  ...      NaN              219
# 2024-11-22  3434.250000  3434.250000  ...      NaN              220
# 2024-11-25  3679.449951  3679.449951  ...      NaN              221
# 2024-11-26  3578.300049  3578.300049  ...      NaN              222
#
# [222 rows x 8 columns]

# %%
column_names = data.columns

# %%
column_names
# Out:
# MultiIndex([(       'Adj Close', 'ANUP.NS'),
#             (           'Close', 'ANUP.NS'),
#             (            'High', 'ANUP.NS'),
#             (             'Low', 'ANUP.NS'),
#             (            'Open', 'ANUP.NS'),
#             (          'Volume', 'ANUP.NS'),
#             (        'purchase',        ''),
#             ('number_of_stocks',        '')],
#            names=['Price', 'Ticker'])

# %%
df=data['Price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\aryan\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df=data['Price']
#
# ...

# %%
df['purchase']=data['Low']
df['number_of_stocks']=range(1, len(data) + 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 df['purchase']=data['Low']
#       2 df['number_of_stocks']=range(1, len(data) + 1)
#
# NameError: name 'df' is not defined

# %%
data
# Out:
# Price         Adj Close        Close  ... purchase number_of_stocks
# Ticker          ANUP.NS      ANUP.NS  ...
# Date                                  ...
# 2024-01-01  1345.895386  1349.625000  ...      NaN                1
# 2024-01-02  1330.163940  1333.849976  ...      NaN                2
# 2024-01-03  1350.657227  1354.400024  ...      NaN                3
# 2024-01-04  1350.931519  1354.675049  ...      NaN                4
# 2024-01-05  1350.482666  1354.224976  ...      NaN                5
# ...                 ...          ...  ...      ...              ...
# 2024-11-19  3413.850098  3413.850098  ...      NaN              218
# 2024-11-21  3488.350098  3488.350098  ...      NaN              219
# 2024-11-22  3434.250000  3434.250000  ...      NaN              220
# 2024-11-25  3679.449951  3679.449951  ...      NaN              221
# 2024-11-26  3578.300049  3578.300049  ...      NaN              222
#
# [222 rows x 8 columns]
